# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
df = pd.read_csv("foods.csv")
df.Item = df.Item.astype("category")
df.Gender = df.Gender.astype("category")
df.City = df.City.astype("category")
df.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
df[pd.isnull(df).sum(axis = 1).astype("bool")]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, City, Frequency, Item, Spend]
# Index: []

# %%
stamf = df[df.City == "Stamford"]

# %%
grouped = df.groupby(df.City)

# %%
grouped.describe()
# Out:
#                          Spend
# City
# New York     count  313.000000
#              mean    50.509808
#              std     27.678569
#              min      1.020000
#              25%     28.560000
#              50%     49.320000
#              75%     73.640000
#              max     99.510000
# Philadelphia count  359.000000
#              mean    49.678384
#              std     27.927305
#              min      1.040000
#              25%     27.100000
#              50%     49.900000
#              75%     72.770000
#              max     99.680000
# Stamford     count  328.000000
#              mean    50.077012
#              std     27.635844
#              min      1.180000
#              25%     26.640000
#              50%     47.930000
#              75%     73.292500
#              max     99.870000

# %%
# ax = plt.subplot()
# for name, group in grouped:
#     group.plot(ax=ax, kind='hist')
# Out:
# <img src="data:image/png;base64,...">
