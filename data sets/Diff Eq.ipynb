# %%
from sympy import symbols, Function
from numpy import linspace, exp 
import matplotlib.pyplot as plt

# %%
t = symbols("t")
f = Function("f")

# %%
f(t).diff(t, t)
# Out:
#   2
#  d
# ───(f(t))
#   2
# dt

# %%
t = linspace(0,10) #time

# %%
p0 = 1 #initial population size
k = 1 #population growth rate

plt.plot(t, p0 * exp(k*t))
plt.plot(t, 2 * exp(k*t))
plt.plot(t, 3 * exp(k*t))
plt.plot(t, 4 * exp(k*t))
plt.plot(t, 4 * exp(k*t))

plt.title("Malthusian growth")
plt.ylabel('Population')

plt.legend(['p0 = 1', 'p0 = 2', 'p0 = 3', 'p0 = 4'], loc='upper left')

# %%
x = np.arange(10)

plt.plot(x, x)
plt.plot(x, 10000 * x)
plt.plot(x, 3 * x)
plt.plot(x, 4 * x)
plt.show()
